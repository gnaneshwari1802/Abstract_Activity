# %% [markdown]
# # python<a href="#python" class="anchor-link">¶</a>
#
# ![image.png](data:image/png;base64,...)
#
# In \[1\]:
#
#     import sys
#     sys.version
#
# Out\[1\]:
#
#     '3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]'
#
# In \[2\]:
#
#     'welcome to fsds with chatgp @10am'
#
# Out\[2\]:
#
#     'welcome to fsds with chatgp @10am'
#
# In \[3\]:
#
#     # 'welcome to fsds with chatgp @10am
#
# ## python idenifier = object = variable<a href="#python-idenifier-=-object-=-variable" class="anchor-link">¶</a>
#
# syntax
#
# = values
#
#     values == <identifier>
#
# In \[4\]:
#
#     a = 5 #a - identifer & 5 is value
#
# a = 5 where a - identifier & 5 - value ( int value) b = 5.6 b- identier
# & 5.6 - float values python is object oriented programin langauage
#
# In \[5\]:
#
#     b = 6
#     b
#
# Out\[5\]:
#
#     6
#
# In \[6\]:
#
#     b = 7
#     b
#
# Out\[6\]:
#
#     7
#
# In \[7\]:
#
#     a = 5
#     type(5)
#
# Out\[7\]:
#
#     int
#
# In \[8\]:
#
#     b = 5.6
#     type(b)
#
# Out\[8\]:
#
#     float
#
# In \[9\]:
#
#     c = 'nit'
#     type(c)
#
# Out\[9\]:
#
#     str
#
# In \[10\]:
#
#     d = True
#     type(d)
#
# Out\[10\]:
#
#     bool
#
# In \[11\]:
#
#     e = False
#     type(e)
#
# Out\[11\]:
#
#     bool
#
# In \[12\]:
#
#     a, b, c, d, e
#
# Out\[12\]:
#
#     (5, 5.6, 'nit', True, False)
#
# In \[13\]:
#
#     id(A)
#
#     ---------------------------------------------------------------------------
#     NameError                                 Traceback (most recent call last)
#     <ipython-input-13-662caf0f44f3> in <module>
#     ----> 1 id(A)
#
#     NameError: name 'A' is not defined
#
# In \[14\]:
#
#     print(id(a))
#     print(id(b))
#     print(id(c))
#     print(id(d))
#     print(id(e))
#
#     140711790748176
#     2652332789968
#     2652296868080
#     140711790225744
#     140711790225776
#
# In \[15\]:
#
#     a = [10, 20, 30, 40, 50]
#     a
#
# Out\[15\]:
#
#     [10, 20, 30, 40, 50]
#
# In \[16\]:
#
#     type(a)
#
# Out\[16\]:
#
#     list
#
# In \[17\]:
#
#     len(a)
#
# Out\[17\]:
#
#     5
#
# print\| len \| type \| id ===> inbuild function
#
# In \[18\]:
#
#     a = 6
#     type(a)
#
# Out\[18\]:
#
#     int
#
# In \[19\]:
#
#     b = 6.7
#     type(b)
#
# Out\[19\]:
#
#     float
#
# ## Rules to define python identifier<a href="#Rules-to-define-python-identifier" class="anchor-link">¶</a>
#
# = values a = 5 a is idetifier - object \|\| 5 -- value
#
# In \[21\]:
#
#     z = 15
#     Z
#
#     ---------------------------------------------------------------------------
#     NameError                                 Traceback (most recent call last)
#     <ipython-input-21-0a00def6ef3f> in <module>
#           1 z = 15
#     ----> 2 Z
#
#     NameError: name 'Z' is not defined
#
# In \[22\]:
#
#     z = 15
#     z
#
# Out\[22\]:
#
#     15
#
# In \[23\]:
#
#     M = 15
#     M
#
# Out\[23\]:
#
#     15
#
# In \[24\]:
#
#     1M = 10
#     1M
#
#       File "<ipython-input-24-4a7463549034>", line 1
#         1M = 10
#          ^
#     SyntaxError: invalid syntax
#
# In \[25\]:
#
#     M1 = 10
#     M1
#
# Out\[25\]:
#
#     10
#
# In \[26\]:
#
#     nare$h = 25000
#     nareh$h
#
#       File "<ipython-input-26-d0ba11964671>", line 1
#         nare$h = 25000
#             ^
#     SyntaxError: invalid syntax
#
# In \[27\]:
#
#     nare*h = 20
#     nare*h
#
#       File "<ipython-input-27-f5ba0a320957>", line 1
#         nare*h = 20
#                    ^
#     SyntaxError: can't assign to operator
#
# In \[28\]:
#
#     naresh_ = 25
#     naresh_
#
# Out\[28\]:
#
#     25
#
# In \[29\]:
#
#     if = 23
#     if
#
#       File "<ipython-input-29-09cbf29e2635>", line 1
#         if = 23
#            ^
#     SyntaxError: invalid syntax
#
# In \[30\]:
#
#     IF = 67
#     IF
#
# Out\[30\]:
#
#     67
#
# In \[31\]:
#
#     If = 89
#     If
#
# Out\[31\]:
#
#     89
#
# In \[32\]:
#
#     for = 67
#     for
#
#       File "<ipython-input-32-4e21b8d4d36b>", line 1
#         for = 67
#             ^
#     SyntaxError: invalid syntax
#
# In \[36\]:
#
#     import keyword
#     keyword.kwlist #wihtout identidier
#
# Out\[36\]:
#
#     ['False',
#      'None',
#      'True',
#      'and',
#      'as',
#      'assert',
#      'async',
#      'await',
#      'break',
#      'class',
#      'continue',
#      'def',
#      'del',
#      'elif',
#      'else',
#      'except',
#      'finally',
#      'for',
#      'from',
#      'global',
#      'if',
#      'import',
#      'in',
#      'is',
#      'lambda',
#      'nonlocal',
#      'not',
#      'or',
#      'pass',
#      'raise',
#      'return',
#      'try',
#      'while',
#      'with',
#      'yield']
#
# In \[37\]:
#
#     k = keyword.kwlist
#     k
#
# Out\[37\]:
#
#     ['False',
#      'None',
#      'True',
#      'and',
#      'as',
#      'assert',
#      'async',
#      'await',
#      'break',
#      'class',
#      'continue',
#      'def',
#      'del',
#      'elif',
#      'else',
#      'except',
#      'finally',
#      'for',
#      'from',
#      'global',
#      'if',
#      'import',
#      'in',
#      'is',
#      'lambda',
#      'nonlocal',
#      'not',
#      'or',
#      'pass',
#      'raise',
#      'return',
#      'try',
#      'while',
#      'with',
#      'yield']
#
# In \[38\]:
#
#     k
#
# Out\[38\]:
#
#     ['False',
#      'None',
#      'True',
#      'and',
#      'as',
#      'assert',
#      'async',
#      'await',
#      'break',
#      'class',
#      'continue',
#      'def',
#      'del',
#      'elif',
#      'else',
#      'except',
#      'finally',
#      'for',
#      'from',
#      'global',
#      'if',
#      'import',
#      'in',
#      'is',
#      'lambda',
#      'nonlocal',
#      'not',
#      'or',
#      'pass',
#      'raise',
#      'return',
#      'try',
#      'while',
#      'with',
#      'yield']
#
# In \[39\]:
#
#     k
#
# Out\[39\]:
#
#     ['False',
#      'None',
#      'True',
#      'and',
#      'as',
#      'assert',
#      'async',
#      'await',
#      'break',
#      'class',
#      'continue',
#      'def',
#      'del',
#      'elif',
#      'else',
#      'except',
#      'finally',
#      'for',
#      'from',
#      'global',
#      'if',
#      'import',
#      'in',
#      'is',
#      'lambda',
#      'nonlocal',
#      'not',
#      'or',
#      'pass',
#      'raise',
#      'return',
#      'try',
#      'while',
#      'with',
#      'yield']
#
# In \[40\]:
#
#     zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz = 9
#
# In \[42\]:
#
#     zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
#
# Out\[42\]:
#
#     9
#
# In \[43\]:
#
#     pi = 3.14
#     pi
#
# Out\[43\]:
#
#     3.14
#
# In \[45\]:
#
#     pi = 3.17
#     pi
#
# Out\[45\]:
#
#     3.17
#
# ## DATA TYPE<a href="#DATA-TYPE" class="anchor-link">¶</a>
#
# -   int -- VALUE WITHOUT DECIMAL
# -   float -- value with decimal
# -   bool -- t or false
# -   complex -- a + bj
# -   string
#
# In \[46\]:
#
#     i = 34
#     i
#
# Out\[46\]:
#
#     34
#
# In \[47\]:
#
#     type(i)
#
# Out\[47\]:
#
#     int
#
# binary (0b) \| octal (0o) 0b1
#
# In \[48\]:
#
#     i = 11
#     i
#
# Out\[48\]:
#
#     11
#
# In \[50\]:
#
#     i_ = 0b11
#     i_
#
# Out\[50\]:
#
#     3
#
# In \[51\]:
#
#     type(i_)
#
# Out\[51\]:
#
#     int
#
# In \[53\]:
#
#     bin(3)
#
# Out\[53\]:
#
#     '0b11'
#
# In \[54\]:
#
#     a1 = 0b10
#     a1
#
# Out\[54\]:
#
#     2
#
# In \[55\]:
#
#     bin(2)
#
# Out\[55\]:
#
#     '0b10'
#
# In \[56\]:
#
#     type(a1)
#
# Out\[56\]:
#
#     int
#
# In \[57\]:
#
#     a
#
# Out\[57\]:
#
#     6
#
# In \[58\]:
#
#     a1
#
# Out\[58\]:
#
#     2
#
# In \[62\]:
#
#     i_
#
# Out\[62\]:
#
#     3
#
# In \[63\]:
#
#     a2 = 0b22
#     a2
#
#       File "<ipython-input-63-9a730224475b>", line 1
#         a2 = 0b22
#               ^
#     SyntaxError: invalid token
#
# In \[64\]:
#
#     a2 = 0b33
#
#       File "<ipython-input-64-bead57604db5>", line 1
#         a2 = 0b33
#               ^
#     SyntaxError: invalid token
#
# In \[66\]:
#
#     a3 = 0b11
#     a3
#
# Out\[66\]:
#
#     3
#
# In \[67\]:
#
#     o = 0o11
#     o
#
# Out\[67\]:
#
#     9
#
# In \[68\]:
#
#     o1 = 0o77
#     o1
#
# Out\[68\]:
#
#     63
#
# In \[70\]:
#
#     o2 = 0o6
#     o1
#
# Out\[70\]:
#
#     63
#
# In \[71\]:
#
#     type(o1)
#
# Out\[71\]:
#
#     int
#
# -   float - value with decimal
#
# In \[72\]:
#
#     f = 2.3
#     f
#
# Out\[72\]:
#
#     2.3
#
# In \[73\]:
#
#     type(f)
#
# Out\[73\]:
#
#     float
#
# In \[74\]:
#
#     f1 = 0b11.1
#
#       File "<ipython-input-74-dc47be7da415>", line 1
#         f1 = 0b11.1
#                   ^
#     SyntaxError: invalid syntax
#
# In \[75\]:
#
#     f2 = 0o1.1
#
#       File "<ipython-input-75-df936e0e2498>", line 1
#         f2 = 0o1.1
#                  ^
#     SyntaxError: invalid syntax
#
# int - value without decimal supports binary integral \| octal integral
# float - value with decimal doesnot support binary \| octal
#
# -   while you check ipcongif - hexadecimal format ( cmd-ipconfig- ipv4
#     adress)
#
# -   COMPLEX DATA TYPE -->
# -   a + bj
# -   a is called real part \|\| b is called imaginary part \|\| j - squre
#     root of -1
#
# In \[76\]:
#
#     c = 10 + 20j
#     c
#
# Out\[76\]:
#
#     (10+20j)
#
# In \[77\]:
#
#     type(c)
#
# Out\[77\]:
#
#     complex
#
# In \[82\]:
#
#     c1 = 10 + 20j
#     c1
#
# Out\[82\]:
#
#     (10+20j)
#
# In \[85\]:
#
#     a3 = 1 + 2j
#     b3 = 3 + 4j
#
# In \[86\]:
#
#     a3.real
#
# Out\[86\]:
#
#     1.0
#
# In \[89\]:
#
#     a3.imag
#
# Out\[89\]:
#
#     2.0
#
# In \[92\]:
#
#     import sys
#     sys.version
#
# Out\[92\]:
#
#     '3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]'
#
# In \[ \]:
#
#     a3 = 1 + 2j
#     b3 = 3 + 4j
#
# In \[97\]:
#
#     print(a3+b3)
#     print(a3-b3)
#     print(a3*b3)
#     print(a3/b3)
#
#     (4+6j)
#     (-2-2j)
#     (-5+10j)
#     (0.44+0.08j)
#
# In \[98\]:
#
#     2 + 3
#
# Out\[98\]:
#
#     5
#
# In \[99\]:
#
#     a = 2
#     b = 3
#     a + b
#
# Out\[99\]:
#
#     5
#
# In \[100\]:
#
#     10 + 5
#
# Out\[100\]:
#
#     15
#
# In \[101\]:
#
#     10 - 5
#
# Out\[101\]:
#
#     5
#
# In \[102\]:
#
#     10 * 5
#
# Out\[102\]:
#
#     50
#
# In \[103\]:
#
#     10 / 5 #float division
#
# Out\[103\]:
#
#     2.0
#
# In \[104\]:
#
#     10 // 5 #int divion
#
# Out\[104\]:
#
#     2
#
# In \[105\]:
#
#     a3
#
# Out\[105\]:
#
#     (1+2j)
#
# # bool --><a href="#bool---%3E" class="anchor-link">¶</a>
#
# In \[106\]:
#
#     True
#
# Out\[106\]:
#
#     True
#
# In \[107\]:
#
#     False
#
# Out\[107\]:
#
#     False
#
# In \[108\]:
#
#     b8 = TRUE
#     b8
#
#     ---------------------------------------------------------------------------
#     NameError                                 Traceback (most recent call last)
#     <ipython-input-108-3f0f9748b8f1> in <module>
#     ----> 1 b8 = TRUE
#           2 b8
#
#     NameError: name 'TRUE' is not defined
#
# In \[109\]:
#
#     b8 = True
#     b8
#
# Out\[109\]:
#
#     True
#
# In \[113\]:
#
#     True = b8
#
#       File "<ipython-input-113-19fa9f7a21e8>", line 1
#         True = b8
#                  ^
#     SyntaxError: can't assign to keyword
#
# In \[114\]:
#
#     type(b8)
#
# Out\[114\]:
#
#     bool
#
# In \[115\]:
#
#     int(True)
#
# Out\[115\]:
#
#     1
#
# In \[116\]:
#
#     int(b8)
#
# Out\[116\]:
#
#     1
#
# In \[117\]:
#
#     b9 = False
#     print(b9)
#     print(int(b9))
#
#     False
#     0
#
# In \[118\]:
#
#     True + True
#
# Out\[118\]:
#
#     2
#
# In \[119\]:
#
#     True + False
#
# Out\[119\]:
#
#     1
#
# In \[120\]:
#
#     True - True
#
# Out\[120\]:
#
#     0
#
# In \[121\]:
#
#     False - False
#
# Out\[121\]:
#
#     0
#
# In \[122\]:
#
#     False / True
#
# Out\[122\]:
#
#     0.0
#
# In \[123\]:
#
#     False // True
#
# Out\[123\]:
#
#     0
#
# In \[124\]:
#
#     True / False
#
#     ---------------------------------------------------------------------------
#     ZeroDivisionError                         Traceback (most recent call last)
#     <ipython-input-124-f8487d9d0863> in <module>
#     ----> 1 True / False
#
#     ZeroDivisionError: division by zero
#
# In \[125\]:
#
#     m1 = True
#     n1 = False
#
# In \[127\]:
#
#     print(m1+n1)
#     print(m1-n1)
#     print(m1*n1)
#     print(m1/n1)
#     print(m1//n1)
#
#     1
#     1
#     0
#
#     ---------------------------------------------------------------------------
#     ZeroDivisionError                         Traceback (most recent call last)
#     <ipython-input-127-6e6f5d68e165> in <module>
#           2 print(m1-n1)
#           3 print(m1*n1)
#     ----> 4 print(m1/n1)
#           5 print(m1//n1)
#
#     ZeroDivisionError: division by zero
#
# In \[128\]:
#
#     print(m1+n1)
#     print(m1-n1)
#     print(m1*n1)
#     print(n1/m1)
#     print(n1//m1)
#
#     1
#     1
#     0
#     0.0
#     0
#
# In \[131\]:
#
#     b = int(10.10)
#
# In \[132\]:
#
#     b
#
# Out\[132\]:
#
#     10
#
# In \[ \]:
