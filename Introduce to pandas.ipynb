# %% [markdown]
# ### Dataframe in python and how to import the dataset
#
# #### pandas are very good package for dataframes &its perfect for dataset& very powerfull packages

# %%
import pandas as pd #USE FOR DATAFRAMES

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
stats = pd.read_csv(r'C:\Users\Gnaneshwari\Desktop\DemographicData.csv')

# %%
# The warning message you're seeing is a "DtypeWarning." It typically occurs when Pandas detects that columns in your CSV file contain mixed data types (e.g., both numeric and non-numeric data) or that the data types in the columns might not match the default data types that Pandas is trying to infer. This warning is just informative and not necessarily an error, but it's important to understand and address it as needed.

# %%
stats
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 0                       Aruba         ABW     10.244           78.9
# 1                 Afghanistan         AFG     35.253            5.9
# 2                      Angola         AGO     45.985           19.1
# 3                     Albania         ALB     12.877           57.2
# 4        United Arab Emirates         ARE     11.044           88.0
# ...                       ...         ...        ...            ...
# 1048510                   NaN         NaN        NaN            NaN
# 1048511                   NaN         NaN        NaN            NaN
# 1048512                   NaN         NaN        NaN            NaN
# 1048513                   NaN         NaN        NaN            NaN
# 1048514                   NaN         NaN        NaN            NaN
#
#                  IncomeGroup
# 0                High income
# 1                 Low income
# 2        Upper middle income
# 3        Upper middle income
# 4                High income
# ...                      ...
# 1048510                  NaN
# 1048511                  NaN
# 1048512                  NaN
# 1048513                  NaN
# 1048514                  NaN
#
# [1048515 rows x 5 columns]

# %%
# Explore data in python
#1. Full dataframe
#2. How many rows & columns. you have to chk the row becuase the no. of raw should matched with client data 

len(stats) #195 rows imported (this is for tracking later part )
# Out:
# 1048515

# %%
stats.shape
# Out:
# (1048515, 5)

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
type(stats)
# Out:
# pandas.core.frame.DataFrame

# %%
stats
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 0                       Aruba         ABW     10.244           78.9
# 1                 Afghanistan         AFG     35.253            5.9
# 2                      Angola         AGO     45.985           19.1
# 3                     Albania         ALB     12.877           57.2
# 4        United Arab Emirates         ARE     11.044           88.0
# ...                       ...         ...        ...            ...
# 1048510                   NaN         NaN        NaN            NaN
# 1048511                   NaN         NaN        NaN            NaN
# 1048512                   NaN         NaN        NaN            NaN
# 1048513                   NaN         NaN        NaN            NaN
# 1048514                   NaN         NaN        NaN            NaN
#
#                  IncomeGroup
# 0                High income
# 1                 Low income
# 2        Upper middle income
# 3        Upper middle income
# 4                High income
# ...                      ...
# 1048510                  NaN
# 1048511                  NaN
# 1048512                  NaN
# 1048513                  NaN
# 1048514                  NaN
#
# [1048515 rows x 5 columns]

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048515 entries, 0 to 1048514
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 40.0+ MB

# %%
#3. see columns
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
#4. Number of columns
len(stats.columns)
# Out:
# 5

# %%
stats.shape # no. of rows and columns
# Out:
# (1048515, 5)

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048515 entries, 0 to 1048514
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 40.0+ MB

# %%
#5. top rows 
#head() 
stats.head()  # it will print top 5 rows
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.tail()
# Out:
#         CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 1048510         NaN         NaN        NaN            NaN         NaN
# 1048511         NaN         NaN        NaN            NaN         NaN
# 1048512         NaN         NaN        NaN            NaN         NaN
# 1048513         NaN         NaN        NaN            NaN         NaN
# 1048514         NaN         NaN        NaN            NaN         NaN

# %%
stats.head(10)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
stats.tail()
# Out:
#         CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 1048510         NaN         NaN        NaN            NaN         NaN
# 1048511         NaN         NaN        NaN            NaN         NaN
# 1048512         NaN         NaN        NaN            NaN         NaN
# 1048513         NaN         NaN        NaN            NaN         NaN
# 1048514         NaN         NaN        NaN            NaN         NaN

# %%
#6. Bottom rows
stats.tail(4) #last 5 rows
# Out:
#         CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 1048511         NaN         NaN        NaN            NaN         NaN
# 1048512         NaN         NaN        NaN            NaN         NaN
# 1048513         NaN         NaN        NaN            NaN         NaN
# 1048514         NaN         NaN        NaN            NaN         NaN

# %%
stats.tail(10)
# Out:
#         CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 1048505         NaN         NaN        NaN            NaN         NaN
# 1048506         NaN         NaN        NaN            NaN         NaN
# 1048507         NaN         NaN        NaN            NaN         NaN
# 1048508         NaN         NaN        NaN            NaN         NaN
# 1048509         NaN         NaN        NaN            NaN         NaN
# 1048510         NaN         NaN        NaN            NaN         NaN
# 1048511         NaN         NaN        NaN            NaN         NaN
# 1048512         NaN         NaN        NaN            NaN         NaN
# 1048513         NaN         NaN        NaN            NaN         NaN
# 1048514         NaN         NaN        NaN            NaN         NaN

# %%
stats.head(10)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
#stats.info()

# it will give information of the dataset

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats.describe()  # descriptive stats
#stats.describe . DESCRBE WIL LGIVE ONLY NUMERICAL INFORMATION
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
#8. get stats on the columns

#stats.describe #it will work like a statistic fun

# %%
stats.describe().transpose() #transpose convert column into rows
# Out:
#                count       mean        std  min      25%    50%      75%  \
# BirthRate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# InternetUsers  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                    max
# BirthRate      49.6610
# InternetUsers  96.5468

# %%
# Renaming columns of a dataframe
stats.head(2)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0        Aruba         ABW     10.244           78.9  High income
# 1  Afghanistan         AFG     35.253            5.9   Low income

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048515 entries, 0 to 1048514
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 40.0+ MB

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats.columns = ['a','b','c','d','e']

# %%
stats.head()
# Out:
#                       a    b       c     d                    e
# 0                 Aruba  ABW  10.244  78.9          High income
# 1           Afghanistan  AFG  35.253   5.9           Low income
# 2                Angola  AGO  45.985  19.1  Upper middle income
# 3               Albania  ALB  12.877  57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0          High income

# %%
stats.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
stats.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers','IncomeGroup']

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# subsetting a dataframes in pandas

#1. Rows
#2. Columns
#3. combine the two

# %%
stats[:]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 0                       Aruba         ABW     10.244           78.9
# 1                 Afghanistan         AFG     35.253            5.9
# 2                      Angola         AGO     45.985           19.1
# 3                     Albania         ALB     12.877           57.2
# 4        United Arab Emirates         ARE     11.044           88.0
# ...                       ...         ...        ...            ...
# 1048510                   NaN         NaN        NaN            NaN
# 1048511                   NaN         NaN        NaN            NaN
# 1048512                   NaN         NaN        NaN            NaN
# 1048513                   NaN         NaN        NaN            NaN
# 1048514                   NaN         NaN        NaN            NaN
#
#                  IncomeGroup
# 0                High income
# 1                 Low income
# 2        Upper middle income
# 3        Upper middle income
# 4                High income
# ...                      ...
# 1048510                  NaN
# 1048511                  NaN
# 1048512                  NaN
# 1048513                  NaN
# 1048514                  NaN
#
# [1048515 rows x 5 columns]

# %%
# Rows:
stats[0:5]  #how python know that only this is rows based on index
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[:]      #it will show entire dataframe
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 0                       Aruba         ABW     10.244           78.9
# 1                 Afghanistan         AFG     35.253            5.9
# 2                      Angola         AGO     45.985           19.1
# 3                     Albania         ALB     12.877           57.2
# 4        United Arab Emirates         ARE     11.044           88.0
# ...                       ...         ...        ...            ...
# 1048510                   NaN         NaN        NaN            NaN
# 1048511                   NaN         NaN        NaN            NaN
# 1048512                   NaN         NaN        NaN            NaN
# 1048513                   NaN         NaN        NaN            NaN
# 1048514                   NaN         NaN        NaN            NaN
#
#                  IncomeGroup
# 0                High income
# 1                 Low income
# 2        Upper middle income
# 3        Upper middle income
# 4                High income
# ...                      ...
# 1048510                  NaN
# 1048511                  NaN
# 1048512                  NaN
# 1048513                  NaN
# 1048514                  NaN
#
# [1048515 rows x 5 columns]

# %%
stats[:10]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
stats.head(10)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
# How to reverse the dataframe

stats[: : -1]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1048514                   NaN         NaN        NaN            NaN
# 1048513                   NaN         NaN        NaN            NaN
# 1048512                   NaN         NaN        NaN            NaN
# 1048511                   NaN         NaN        NaN            NaN
# 1048510                   NaN         NaN        NaN            NaN
# ...                       ...         ...        ...            ...
# 4        United Arab Emirates         ARE     11.044           88.0
# 3                     Albania         ALB     12.877           57.2
# 2                      Angola         AGO     45.985           19.1
# 1                 Afghanistan         AFG     35.253            5.9
# 0                       Aruba         ABW     10.244           78.9
#
#                  IncomeGroup
# 1048514                  NaN
# 1048513                  NaN
# 1048512                  NaN
# 1048511                  NaN
# 1048510                  NaN
# ...                      ...
# 4                High income
# 3        Upper middle income
# 2        Upper middle income
# 1                 Low income
# 0                High income
#
# [1048515 rows x 5 columns]

# %%
stats[: -1]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 0                       Aruba         ABW     10.244           78.9
# 1                 Afghanistan         AFG     35.253            5.9
# 2                      Angola         AGO     45.985           19.1
# 3                     Albania         ALB     12.877           57.2
# 4        United Arab Emirates         ARE     11.044           88.0
# ...                       ...         ...        ...            ...
# 1048509                   NaN         NaN        NaN            NaN
# 1048510                   NaN         NaN        NaN            NaN
# 1048511                   NaN         NaN        NaN            NaN
# 1048512                   NaN         NaN        NaN            NaN
# 1048513                   NaN         NaN        NaN            NaN
#
#                  IncomeGroup
# 0                High income
# 1                 Low income
# 2        Upper middle income
# 3        Upper middle income
# 4                High income
# ...                      ...
# 1048509                  NaN
# 1048510                  NaN
# 1048511                  NaN
# 1048512                  NaN
# 1048513                  NaN
#
# [1048514 rows x 5 columns]

# %%
stats
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 0                       Aruba         ABW     10.244           78.9
# 1                 Afghanistan         AFG     35.253            5.9
# 2                      Angola         AGO     45.985           19.1
# 3                     Albania         ALB     12.877           57.2
# 4        United Arab Emirates         ARE     11.044           88.0
# ...                       ...         ...        ...            ...
# 1048510                   NaN         NaN        NaN            NaN
# 1048511                   NaN         NaN        NaN            NaN
# 1048512                   NaN         NaN        NaN            NaN
# 1048513                   NaN         NaN        NaN            NaN
# 1048514                   NaN         NaN        NaN            NaN
#
#                  IncomeGroup
# 0                High income
# 1                 Low income
# 2        Upper middle income
# 3        Upper middle income
# 4                High income
# ...                      ...
# 1048510                  NaN
# 1048511                  NaN
# 1048512                  NaN
# 1048513                  NaN
# 1048514                  NaN
#
# [1048515 rows x 5 columns]

# %%
# get only every 20th row
stats[: :  10]
# Out:
#         CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0             Aruba         ABW     10.244          78.90          High income
# 10       Azerbaijan         AZE     18.300          58.70  Upper middle income
# 20          Belarus         BLR     12.500          54.17  Upper middle income
# 30           Canada         CAN     10.900          85.80          High income
# 40       Costa Rica         CRI     15.022          45.96  Upper middle income
# ...             ...         ...        ...            ...                  ...
# 1048470         NaN         NaN        NaN            NaN                  NaN
# 1048480         NaN         NaN        NaN            NaN                  NaN
# 1048490         NaN         NaN        NaN            NaN                  NaN
# 1048500         NaN         NaN        NaN            NaN                  NaN
# 1048510         NaN         NaN        NaN            NaN                  NaN
#
# [104852 rows x 5 columns]

# %%
# COLUMNS: 

stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 0                       Aruba         ABW     10.244           78.9
# 1                 Afghanistan         AFG     35.253            5.9
# 2                      Angola         AGO     45.985           19.1
# 3                     Albania         ALB     12.877           57.2
# 4        United Arab Emirates         ARE     11.044           88.0
# ...                       ...         ...        ...            ...
# 1048510                   NaN         NaN        NaN            NaN
# 1048511                   NaN         NaN        NaN            NaN
# 1048512                   NaN         NaN        NaN            NaN
# 1048513                   NaN         NaN        NaN            NaN
# 1048514                   NaN         NaN        NaN            NaN
#
#                  IncomeGroup
# 0                High income
# 1                 Low income
# 2        Upper middle income
# 3        Upper middle income
# 4                High income
# ...                      ...
# 1048510                  NaN
# 1048511                  NaN
# 1048512                  NaN
# 1048513                  NaN
# 1048514                  NaN
#
# [1048515 rows x 5 columns]

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats['IncomeGroup']
# Out:
# 0                  High income
# 1                   Low income
# 2          Upper middle income
# 3          Upper middle income
# 4                  High income
#                   ...
# 1048510                    NaN
# 1048511                    NaN
# 1048512                    NaN
# 1048513                    NaN
# 1048514                    NaN
# Name: IncomeGroup, Length: 1048515, dtype: object

# %%
['CountryName','BirthRate']
# Out:
# ['CountryName', 'BirthRate']

# %%
stats[['CountryName','BirthRate']]
# Out:
#                   CountryName  BirthRate
# 0                       Aruba     10.244
# 1                 Afghanistan     35.253
# 2                      Angola     45.985
# 3                     Albania     12.877
# 4        United Arab Emirates     11.044
# ...                       ...        ...
# 1048510                   NaN        NaN
# 1048511                   NaN        NaN
# 1048512                   NaN        NaN
# 1048513                   NaN        NaN
# 1048514                   NaN        NaN
#
# [1048515 rows x 2 columns]

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats['BirthRate'].head()
# Out:
# 0    10.244
# 1    35.253
# 2    45.985
# 3    12.877
# 4    11.044
# Name: BirthRate, dtype: float64

# %%
stats[4:8]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
# 7   Antigua and Barbuda         ATG     16.447           63.4
#
#            IncomeGroup
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income

# %%
# combine the two
stats[4:8][['CountryName','BirthRate']]
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
stats [['CountryName','BirthRate']][4:8]
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
df1 = stats [['CountryName','BirthRate']]

# %%
df1
# Out:
#                   CountryName  BirthRate
# 0                       Aruba     10.244
# 1                 Afghanistan     35.253
# 2                      Angola     45.985
# 3                     Albania     12.877
# 4        United Arab Emirates     11.044
# ...                       ...        ...
# 1048510                   NaN        NaN
# 1048511                   NaN        NaN
# 1048512                   NaN        NaN
# 1048513                   NaN        NaN
# 1048514                   NaN        NaN
#
# [1048515 rows x 2 columns]

# %%
df2 = stats[4:8]

# %%
df2
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
# 7   Antigua and Barbuda         ATG     16.447           63.4
#
#            IncomeGroup
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income

# %%
# Basic operatioin of dataframe
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[['CountryCode','BirthRate','InternetUsers']][4:8] #subet dataframe
# Out:
#   CountryCode  BirthRate  InternetUsers
# 4         ARE     11.044           88.0
# 5         ARG     17.716           59.9
# 6         ARM     13.308           41.9
# 7         ATG     16.447           63.4

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Mathmetical operation = 
stats.BirthRate * stats.InternetUsers
# Out:
# 0          808.2516
# 1          207.9927
# 2          878.3135
# 3          736.5644
# 4          971.8720
#              ...
# 1048510         NaN
# 1048511         NaN
# 1048512         NaN
# 1048513         NaN
# 1048514         NaN
# Length: 1048515, dtype: float64

# %%
stats
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 0                       Aruba         ABW     10.244           78.9
# 1                 Afghanistan         AFG     35.253            5.9
# 2                      Angola         AGO     45.985           19.1
# 3                     Albania         ALB     12.877           57.2
# 4        United Arab Emirates         ARE     11.044           88.0
# ...                       ...         ...        ...            ...
# 1048510                   NaN         NaN        NaN            NaN
# 1048511                   NaN         NaN        NaN            NaN
# 1048512                   NaN         NaN        NaN            NaN
# 1048513                   NaN         NaN        NaN            NaN
# 1048514                   NaN         NaN        NaN            NaN
#
#                  IncomeGroup
# 0                High income
# 1                 Low income
# 2        Upper middle income
# 3        Upper middle income
# 4                High income
# ...                      ...
# 1048510                  NaN
# 1048511                  NaN
# 1048512                  NaN
# 1048513                  NaN
# 1048514                  NaN
#
# [1048515 rows x 5 columns]

# %%
# Add a column

stats['myCalc'] = stats.BirthRate * stats.InternetUsers

# %%
stats
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 0                       Aruba         ABW     10.244           78.9
# 1                 Afghanistan         AFG     35.253            5.9
# 2                      Angola         AGO     45.985           19.1
# 3                     Albania         ALB     12.877           57.2
# 4        United Arab Emirates         ARE     11.044           88.0
# ...                       ...         ...        ...            ...
# 1048510                   NaN         NaN        NaN            NaN
# 1048511                   NaN         NaN        NaN            NaN
# 1048512                   NaN         NaN        NaN            NaN
# 1048513                   NaN         NaN        NaN            NaN
# 1048514                   NaN         NaN        NaN            NaN
#
#                  IncomeGroup    myCalc
# 0                High income  808.2516
# 1                 Low income  207.9927
# 2        Upper middle income  878.3135
# 3        Upper middle income  736.5644
# 4                High income  971.8720
# ...                      ...       ...
# 1048510                  NaN       NaN
# 1048511                  NaN       NaN
# 1048512                  NaN       NaN
# 1048513                  NaN       NaN
# 1048514                  NaN       NaN
#
# [1048515 rows x 6 columns]

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup', 'myCalc'],
#       dtype='object')

# %%
len(stats.columns)
# Out:
# 6

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    myCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 0                       Aruba         ABW     10.244           78.9
# 1                 Afghanistan         AFG     35.253            5.9
# 2                      Angola         AGO     45.985           19.1
# 3                     Albania         ALB     12.877           57.2
# 4        United Arab Emirates         ARE     11.044           88.0
# ...                       ...         ...        ...            ...
# 1048510                   NaN         NaN        NaN            NaN
# 1048511                   NaN         NaN        NaN            NaN
# 1048512                   NaN         NaN        NaN            NaN
# 1048513                   NaN         NaN        NaN            NaN
# 1048514                   NaN         NaN        NaN            NaN
#
#                  IncomeGroup    myCalc
# 0                High income  808.2516
# 1                 Low income  207.9927
# 2        Upper middle income  878.3135
# 3        Upper middle income  736.5644
# 4                High income  971.8720
# ...                      ...       ...
# 1048510                  NaN       NaN
# 1048511                  NaN       NaN
# 1048512                  NaN       NaN
# 1048513                  NaN       NaN
# 1048514                  NaN       NaN
#
# [1048515 rows x 6 columns]

# %%
stats = stats.drop('myCalc',axis = 1)

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats.columns[3:4]
# Out:
# Index(['InternetUsers'], dtype='object')

# %%
stats
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 0                       Aruba         ABW     10.244           78.9
# 1                 Afghanistan         AFG     35.253            5.9
# 2                      Angola         AGO     45.985           19.1
# 3                     Albania         ALB     12.877           57.2
# 4        United Arab Emirates         ARE     11.044           88.0
# ...                       ...         ...        ...            ...
# 1048510                   NaN         NaN        NaN            NaN
# 1048511                   NaN         NaN        NaN            NaN
# 1048512                   NaN         NaN        NaN            NaN
# 1048513                   NaN         NaN        NaN            NaN
# 1048514                   NaN         NaN        NaN            NaN
#
#                  IncomeGroup
# 0                High income
# 1                 Low income
# 2        Upper middle income
# 3        Upper middle income
# 4                High income
# ...                      ...
# 1048510                  NaN
# 1048511                  NaN
# 1048512                  NaN
# 1048513                  NaN
# 1048514                  NaN
#
# [1048515 rows x 5 columns]

# %%
stats.InternetUsers<2 #we are checking given condition if its correct true or false
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048510    False
# 1048511    False
# 1048512    False
# 1048513    False
# 1048514    False
# Name: InternetUsers, Length: 1048515, dtype: bool

# %%
stats
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 0                       Aruba         ABW     10.244           78.9
# 1                 Afghanistan         AFG     35.253            5.9
# 2                      Angola         AGO     45.985           19.1
# 3                     Albania         ALB     12.877           57.2
# 4        United Arab Emirates         ARE     11.044           88.0
# ...                       ...         ...        ...            ...
# 1048510                   NaN         NaN        NaN            NaN
# 1048511                   NaN         NaN        NaN            NaN
# 1048512                   NaN         NaN        NaN            NaN
# 1048513                   NaN         NaN        NaN            NaN
# 1048514                   NaN         NaN        NaN            NaN
#
#                  IncomeGroup
# 0                High income
# 1                 Low income
# 2        Upper middle income
# 3        Upper middle income
# 4                High income
# ...                      ...
# 1048510                  NaN
# 1048511                  NaN
# 1048512                  NaN
# 1048513                  NaN
# 1048514                  NaN
#
# [1048515 rows x 5 columns]

# %%
Filter = stats.InternetUsers < 2

# %%
Filter
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048510    False
# 1048511    False
# 1048512    False
# 1048513    False
# 1048514    False
# Name: InternetUsers, Length: 1048515, dtype: bool

# %%
stats
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 0                       Aruba         ABW     10.244           78.9
# 1                 Afghanistan         AFG     35.253            5.9
# 2                      Angola         AGO     45.985           19.1
# 3                     Albania         ALB     12.877           57.2
# 4        United Arab Emirates         ARE     11.044           88.0
# ...                       ...         ...        ...            ...
# 1048510                   NaN         NaN        NaN            NaN
# 1048511                   NaN         NaN        NaN            NaN
# 1048512                   NaN         NaN        NaN            NaN
# 1048513                   NaN         NaN        NaN            NaN
# 1048514                   NaN         NaN        NaN            NaN
#
#                  IncomeGroup
# 0                High income
# 1                 Low income
# 2        Upper middle income
# 3        Upper middle income
# 4                High income
# ...                      ...
# 1048510                  NaN
# 1048511                  NaN
# 1048512                  NaN
# 1048513                  NaN
# 1048514                  NaN
#
# [1048515 rows x 5 columns]

# %%
stats[3:7]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
#
#            IncomeGroup
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income

# %%
stats[30:40:3]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 30       Canada         CAN     10.900           85.8          High income
# 33        China         CHN     12.100           45.8  Upper middle income
# 36  Congo, Rep.         COG     37.011            6.6  Lower middle income
# 39   Cabo Verde         CPV     21.625           37.5  Lower middle income

# %%
Filter ## internet user<2
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048510    False
# 1048511    False
# 1048512    False
# 1048513    False
# 1048514    False
# Name: InternetUsers, Length: 1048515, dtype: bool

# %%
stats[Filter]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
len(stats[Filter])
# Out:
# 9

# %%
stats
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 0                       Aruba         ABW     10.244           78.9
# 1                 Afghanistan         AFG     35.253            5.9
# 2                      Angola         AGO     45.985           19.1
# 3                     Albania         ALB     12.877           57.2
# 4        United Arab Emirates         ARE     11.044           88.0
# ...                       ...         ...        ...            ...
# 1048510                   NaN         NaN        NaN            NaN
# 1048511                   NaN         NaN        NaN            NaN
# 1048512                   NaN         NaN        NaN            NaN
# 1048513                   NaN         NaN        NaN            NaN
# 1048514                   NaN         NaN        NaN            NaN
#
#                  IncomeGroup
# 0                High income
# 1                 Low income
# 2        Upper middle income
# 3        Upper middle income
# 4                High income
# ...                      ...
# 1048510                  NaN
# 1048511                  NaN
# 1048512                  NaN
# 1048513                  NaN
# 1048514                  NaN
#
# [1048515 rows x 5 columns]

# %%
stats.BirthRate>40
# Out:
# 0          False
# 1          False
# 2           True
# 3          False
# 4          False
#            ...
# 1048510    False
# 1048511    False
# 1048512    False
# 1048513    False
# 1048514    False
# Name: BirthRate, Length: 1048515, dtype: bool

# %%
Filter2 = stats.BirthRate>40

# %%
Filter2
# Out:
# 0          False
# 1          False
# 2           True
# 3          False
# 4          False
#            ...
# 1048510    False
# 1048511    False
# 1048512    False
# 1048513    False
# 1048514    False
# Name: BirthRate, Length: 1048515, dtype: bool

# %%
len(Filter2)
# Out:
# 1048515

# %%
stats[Filter2]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# 128  Lower middle income
# 156           Low income
# 167           Low income
# 178           Low income
# 192           Low income
# 193  Lower middle income

# %%
#Filter and Filter2 
Filter & Filter2
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048510    False
# 1048511    False
# 1048512    False
# 1048513    False
# 1048514    False
# Length: 1048515, dtype: bool

# %%
stats[Filter & Filter2]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
stats[(stats.BirthRate > 40) & (stats.InternetUsers < 2)]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[stats.IncomeGroup == 'Low income']
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 29   Central African Republic         CAF     34.076           3.50
# 38                    Comoros         COM     34.326           6.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# 64                     Guinea         GIN     37.337           1.60
# 65                Gambia, The         GMB     42.525          14.00
# 66              Guinea-Bissau         GNB     37.503           3.10
# 77                      Haiti         HTI     25.345          10.60
# 93                   Cambodia         KHM     24.462           6.80
# 99                    Liberia         LBR     35.521           3.20
# 111                Madagascar         MDG     34.686           3.00
# 115                      Mali         MLI     44.138           3.50
# 120                Mozambique         MOZ     39.705           5.40
# 123                    Malawi         MWI     39.459           5.05
# 127                     Niger         NER     49.661           1.70
# 132                     Nepal         NPL     20.923          13.30
# 148                    Rwanda         RWA     32.689           9.00
# 154              Sierra Leone         SLE     36.729           1.70
# 156                   Somalia         SOM     43.891           1.50
# 158               South Sudan         SSD     37.126          14.10
# 167                      Chad         TCD     45.745           2.30
# 168                      Togo         TGO     36.080           4.50
# 177                  Tanzania         TZA     39.518           4.40
# 178                    Uganda         UGA     43.474          16.20
# 192          Congo, Dem. Rep.         COD     42.394           2.20
# 194                  Zimbabwe         ZWE     35.715          18.50
#
#     IncomeGroup
# 1    Low income
# 11   Low income
# 13   Low income
# 14   Low income
# 29   Low income
# 38   Low income
# 52   Low income
# 55   Low income
# 64   Low income
# 65   Low income
# 66   Low income
# 77   Low income
# 93   Low income
# 99   Low income
# 111  Low income
# 115  Low income
# 120  Low income
# 123  Low income
# 127  Low income
# 132  Low income
# 148  Low income
# 154  Low income
# 156  Low income
# 158  Low income
# 167  Low income
# 168  Low income
# 177  Low income
# 178  Low income
# 192  Low income
# 194  Low income

# %%
# How to get the unique categories

stats.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income', nan], dtype=object)

# %%
# Introduction to seaborn # seaborn is very powerfull visualizatio(STATISTIC VISULAIZATION) pkg in python

import matplotlib.pyplot as plt # visulaiztion
import seaborn as sns # distribution visualtion 
# seaborn are used for advance visualization e.x --> distribution plot, line plot

# %matplotlib inline 
plt.rcParams['figure.figsize'] = 10,5

import warnings
warnings.filterwarnings('ignore') # os error

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats["InternetUsers"]
# Out:
# 0          78.9
# 1           5.9
# 2          19.1
# 3          57.2
# 4          88.0
#            ...
# 1048510     NaN
# 1048511     NaN
# 1048512     NaN
# 1048513     NaN
# 1048514     NaN
# Name: InternetUsers, Length: 1048515, dtype: float64

# %%
# Distributions: 
vis1 = sns.distplot(stats["InternetUsers"])  # UNIVARIATE ANALYSIS - statistics

# %%
vis1 = sns.distplot(stats["InternetUsers"], bins=20)

# %%
#BOX PLOTS:
vis2 = sns.boxplot( data = stats, x="IncomeGroup", y='BirthRate')  #BI-VARIATE ANALYSIS

# %%
# refer to seaborn gallary

# %%
# visualizing with seaborn

# %%
vis4 = sns.lmplot(data = stats,x = 'InternetUsers', y = 'BirthRate')

# %%
vis3 = sns.lmplot(data = stats,x = 'InternetUsers', y = 'BirthRate', fit_reg = False ) #lm - linear model

# %%
vis31 = sns.lmplot(data = stats,x = 'InternetUsers', y = 'BirthRate', fit_reg = True) #lm - linear model

# %%
vis5 = sns.lmplot(data = stats,x = 'InternetUsers', y = 'BirthRate',
                  fit_reg = False,hue = 'IncomeGroup') #hue - parameter for color

# %%
vis5 = sns.lmplot(data = stats,x = 'InternetUsers', y = 'BirthRate',
                  fit_reg = True,hue = 'IncomeGroup', height = 7)

# %% [markdown]
# # In this section we learned
#
# 1> importing data into python
# 2> Dataframe via panda
# 3> exploring datasets: head()tail()info()describe()
# 4> Renaming columns
# 5> subsetting dataframes
# 6> Basic operations with dataframe
# 8> filtering data frames
# 9> seaborn introduction
