# %%
# USING IRIS DATA SET FOR ANALYSIS

# %%
#  The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor).
# Four features were measured from each sample: the length and the width of the sepals and petals, in centimetres. 
#     Based on the combination of these four features, Fisher developed a linear discriminant model to distinguish the species from each other.

# %% [markdown]
# ![1h.jpg](attachment:1h.jpg)

# %%
# Case Study and Practice in Python: IRIS Data Set

# %%
# This data sets consists of 3 different types of irises' (Setosa, Versicolour, and Virginica) petal and sepal length, stored in a 150x4 numpy.ndarray.

# %%
# The rows being the samples and the columns being: Sepal Length, Sepal Width, Petal Length and Petal Width. The below plot uses the first two features.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import datasets
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
Download Iris data and see the output

# %%
sns.set(color_codes=True)
# %matplotlib inline
dataset=pd.read_csv(r"C:\Users\Gnaneshwari\Desktop\iris.csv")
print(dataset)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
DROP ID COLUMN

# %%
dataset=dataset.drop('Id',axis=1)
dataset.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dataset.shape
# Out:
# (150, 5)

# %%
dataset.info
# Out:
# <bound method DataFrame.info of      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
dataset.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
Use ‘groupby’ to combine

# %%
dataset.groupby('Species').size()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
Box and ‘whisker’ plot

# %%
dataset.plot(kind='box',sharex=False,sharey=False)
# Out:
# <Axes: >

# %%
#Histograms
dataset.hist(edgecolor='black',linewidth=1.2)
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>,
#         <Axes: title={'center': 'SepalWidthCm'}>],
#        [<Axes: title={'center': 'PetalLengthCm'}>,
#         <Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %%
#boxplot on each feature split out by species
dataset.boxplot(by="Species",figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'PetalWidthCm'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'SepalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
#violinplots on petal-length for each species
sns.violinplot(data=dataset,x="Species",y="PetalLengthCm")
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
from pandas.plotting import scatter_matrix
#scatter plot matrix
scatter_matrix(dataset,figsize=(10,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       2 #scatter plot matrix
#       3 scatter_matrix(dataset,figsize=(10,10))
# ----> 4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
#scatter plot matrix
scatter_matrix(dataset,figsize=(10,10))
plt.show()

# %%
sns.pairplot(dataset,hue="Species")
# Out:
# C:\Users\Gnaneshwari\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Importing metrics for evaluation
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
#Seperating the data into dependent and independent variables
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values

# %%
# #Seperating the dataset into the training set and test set
# from sklearn.cross_validation import train_test_split
# X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[29], line 2
#       1 #Seperating the dataset into the training set and test set
# ----> 2 from sklearn.cross_validation import train_test_split
#       3 X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)
#
# ModuleNotFoundError: No module named 'sklearn.cross_validation'

# %%
#Seperating the dataset into the training set and test set
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
X_train,X_test,y_train,y_test
# Out:
# (array([[6.4, 3.1, 5.5, 1.8],
#         [5.4, 3. , 4.5, 1.5],
#         [5.2, 3.5, 1.5, 0.2],
#         [6.1, 3. , 4.9, 1.8],
#         [6.4, 2.8, 5.6, 2.2],
#         [5.2, 2.7, 3.9, 1.4],
#         [5.7, 3.8, 1.7, 0.3],
#         [6. , 2.7, 5.1, 1.6],
#         [5.9, 3. , 4.2, 1.5],
#         [5.8, 2.6, 4. , 1.2],
#         [6.8, 3. , 5.5, 2.1],
#         [4.7, 3.2, 1.3, 0.2],
#         [6.9, 3.1, 5.1, 2.3],
#         [5. , 3.5, 1.6, 0.6],
#         [5.4, 3.7, 1.5, 0.2],
#         [5. , 2. , 3.5, 1. ],
#         [6.5, 3. , 5.5, 1.8],
#         [6.7, 3.3, 5.7, 2.5],
#         [6. , 2.2, 5. , 1.5],
#         [6.7, 2.5, 5.8, 1.8],
#         [5.6, 2.5, 3.9, 1.1],
#         [7.7, 3. , 6.1, 2.3],
#         [6.3, 3.3, 4.7, 1.6],
#         [5.5, 2.4, 3.8, 1.1],
#         [6.3, 2.7, 4.9, 1.8],
#         [6.3, 2.8, 5.1, 1.5],
#         [4.9, 2.5, 4.5, 1.7],
#         [6.3, 2.5, 5. , 1.9],
#         [7. , 3.2, 4.7, 1.4],
#         [6.5, 3. , 5.2, 2. ],
#         [6. , 3.4, 4.5, 1.6],
# ...

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)
# Out:
# C:\Users\Gnaneshwari\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# The warning message you're seeing is related to logistic regression in scikit-learn and specifically the LBFGS solver. This warning suggests that the solver reached the maximum number of iterations without converging to a solution. Convergence in the context of logistic regression means that the algorithm has found the optimal coefficients (weights) for the model.

# You can address this warning by taking one or more of the following steps:

# Increase the number of iterations (max_iter): The warning message suggests increasing the max_iter parameter when creating your logistic regression model. This parameter controls the maximum number of iterations the solver is allowed to run. You can set it to a higher value to allow more iterations. For example:

# python
# Copy code
# from sklearn.linear_model import LogisticRegression
# model = LogisticRegression(solver='lbfgs', max_iter=1000)
# Scale your data: If your input features have very different scales or variances, it can make it difficult for the solver to converge. Scaling your data, for example using StandardScaler from scikit-learn, can help in achieving convergence. Here's how you can use it:

# python
# Copy code
# from sklearn.preprocessing import StandardScaler

# # Scale your input features
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)

# # Then, fit your logistic regression model on the scaled data
# model.fit(X_train_scaled, y_train)
# Choose a different solver: Scikit-learn provides several solvers for logistic regression. If LBFGS isn't working well for your data, you can try other solvers like 'liblinear' or 'sag'. For example:

# python
# Copy code
# model = LogisticRegression(solver='liblinear', max_iter=1000)
# Try these steps to address the convergence warning and achieve a well-converged logistic regression model. It's important to select the most suitable approach based on your data and problem.

# %%
#Summary of the predictions made by the classifier
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         6
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
#
# [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]

# %%
#Accuracy score
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_test,y_pred))
# Out:
# accuracy is 1.0

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier()
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)
#Summary of the predictions made by the classifier
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
#Accuracy score
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         6
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
#
# [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]
# accuracy is 1.0
